# %%
print("bapdada")
# Out:
# bapdada

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.plot(5, 5, 'o')
plt.show()

# %%
plt.plot(5,5,'o')
plt.xlabel("X")
plt.ylabel('Y')
plt.title("Plotting Example")
plt.show()
